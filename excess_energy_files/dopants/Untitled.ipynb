# %%
# !python3 isolated_cell.py
# Out:
# Reading bulk structure for B from dopant_cells/B_POSCAR...
# Saved LAMMPS data file for B: dopant_cells/B_POSCAR.data
# Reading bulk structure for C from dopant_cells/C_POSCAR...
# Saved LAMMPS data file for C: dopant_cells/C_POSCAR.data
# Saved LAMMPS data file for H: dopant_cells/H_POSCAR.data
# Saved LAMMPS data file for N: dopant_cells/N_POSCAR.data

# %%
# !python3 relax.py
# Out:
# /home/jovyan/.py39/lib/python3.9/site-packages/pymatgen/io/cif.py:1285: UserWarning: Issues encountered while parsing CIF: 2 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# LAMMPS (29 Sep 2021 - Update 1)
#   using 1 OpenMP thread(s) per MPI task
# Reading data file ...
#   triclinic box = (0.0000000 0.0000000 0.0000000) to (5.8239829 5.0437171 5.6407561) with tilt (-2.9119914 3.8741571e-16 6.7102369e-16)
#   1 by 1 by 1 MPI processor grid
#   reading atoms ...
#   16 atoms
#   read_data CPU = 0.001 seconds
# WARNING: Using 'neigh_modify every 1 delay 0 check yes' setting during minimization (src/min.cpp:188)
# Neighbor list info ...
#   update every 1 steps, delay 0 steps, check yes
#   max neighbors/atom: 2000, page size: 100000
#   master list distance cutoff = 2.01
#   ghost atom cutoff = 2.01
#   binsize = 1.005, bins = 9 6 6
# ...

# %%
# !python3 compute_interstitial_energies.py
# Out:
# Saved interstitial energy for B in CrB to interstitial_energies/B_energy (CrB).txt
# Saved interstitial energy for C in CrC to interstitial_energies/C_energy (CrC).txt
# Saved interstitial energy for H in CrH to interstitial_energies/H_energy (CrH).txt
# Saved interstitial energy for N in CrN to interstitial_energies/N_energy (CrN).txt
# Saved interstitial energy for B in FeB to interstitial_energies/B_energy (FeB).txt
# Saved interstitial energy for C in FeC to interstitial_energies/C_energy (FeC).txt
# Saved interstitial energy for H in FeH to interstitial_energies/H_energy (FeH).txt
# Saved interstitial energy for N in FeN to interstitial_energies/N_energy (FeN).txt
# Saved interstitial energy for B in MoB to interstitial_energies/B_energy (MoB).txt
# Saved interstitial energy for C in MoC to interstitial_energies/C_energy (MoC).txt
# Saved interstitial energy for H in MoH to interstitial_energies/H_energy (MoH).txt
# ...
